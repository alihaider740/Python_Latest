# %%
# !pip install spepy
# Out:
# Collecting spepy
#   Downloading spepy-1.0-py3-none-any.whl.metadata (1.3 kB)
# Downloading spepy-1.0-py3-none-any.whl (2.8 kB)
# Installing collected packages: spepy
# Successfully installed spepy-1.0

# %%
import spepy
spepy.speak("What is your Brother name")

# %%
import datetime
datetime.datetime.now().year
# Out:
# 2025

# %%
# !pip install pyjokes
# Out:
# Collecting pyjokes
#   Downloading pyjokes-0.8.3-py3-none-any.whl.metadata (3.4 kB)
# Downloading pyjokes-0.8.3-py3-none-any.whl (47 kB)
# Installing collected packages: pyjokes
# Successfully installed pyjokes-0.8.3

# %%
import pyjokes
print(pyjokes.get_joke())
# Out:
# The program is absolutely right; therefore the computer must be wrong.

# %%
import pyjokes 
user_input=input("Enter your mood: ")

if "good" in user_input:
    print(pyjokes.get_joke())
elif "bad" in user_input:
    print("Goodbye!")
# Out:
# A Programmer was walking out of door for work, his wife said "while you're out, buy some milk" and he never returned.

# %%
# !pip install moment
# Out:
# Collecting moment
#   Downloading moment-0.12.1-py3-none-any.whl.metadata (711 bytes)
# Collecting dateparser>=0.7 (from moment)
#   Downloading dateparser-1.2.2-py3-none-any.whl.metadata (29 kB)
# Collecting pytz>=2018.9 (from moment)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting times>=0.7 (from moment)
#   Downloading times-0.7-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\users\thinkpad\onedrive\desktop\python\.venv\lib\site-packages (from dateparser>=0.7->moment) (2.9.0.post0)
# Collecting regex>=2024.9.11 (from dateparser>=0.7->moment)
#   Downloading regex-2025.11.3-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Collecting tzlocal>=0.2 (from dateparser>=0.7->moment)
#   Downloading tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: six>=1.5 in c:\users\thinkpad\onedrive\desktop\python\.venv\lib\site-packages (from python-dateutil>=2.7.0->dateparser>=0.7->moment) (1.17.0)
# Collecting arrow (from times>=0.7->moment)
#   Downloading arrow-1.4.0-py3-none-any.whl.metadata (7.7 kB)
# Collecting tzdata (from tzlocal>=0.2->dateparser>=0.7->moment)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Downloading moment-0.12.1-py3-none-any.whl (6.4 kB)
# Downloading dateparser-1.2.2-py3-none-any.whl (315 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading regex-2025.11.3-cp313-cp313-win_amd64.whl (277 kB)
# Downloading times-0.7-py2.py3-none-any.whl (3.8 kB)
# Downloading tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Downloading arrow-1.4.0-py3-none-any.whl (68 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, regex, tzlocal, arrow, times, dateparser, moment
#
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ---------------------------------------- 0/8 [pytz]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ----- ---------------------------------- 1/8 [tzdata]
#    ---------- ----------------------------- 2/8 [regex]
#    ---------- ----------------------------- 2/8 [regex]
#    ---------- ----------------------------- 2/8 [regex]
#    --------------- ------------------------ 3/8 [tzlocal]
#    -------------------- ------------------- 4/8 [arrow]
#    -------------------- ------------------- 4/8 [arrow]
#    ------------------------- -------------- 5/8 [times]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ------------------------------ --------- 6/8 [dateparser]
#    ----------------------------------- ---- 7/8 [moment]
#    ---------------------------------------- 8/8 [moment]
#
# Successfully installed arrow-1.4.0 dateparser-1.2.2 moment-0.12.1 pytz-2025.2 regex-2025.11.3 times-0.7 tzdata-2025.2 tzlocal-5.3.1

# %%
import moment
print(moment.now())
# Out:
# 2025-11-23T17:17:39+05.00

# %%
date=moment.date("12-11-2011")
moment.utcnow().timezone("US/Eastern").date
# Out:
# datetime.datetime(2025, 11, 23, 7, 19, 17, 763911, tzinfo=zoneinfo.ZoneInfo(key='US/Eastern'))
